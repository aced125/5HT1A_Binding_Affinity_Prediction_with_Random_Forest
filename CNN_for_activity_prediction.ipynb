# %% [markdown]
# <a href="https://colab.research.google.com/github/aced125/5HT1A_Binding_Affinity_Prediction_with_Random_Forest/blob/master/CNN_for_activity_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
# Out:
# --2019-07-23 15:38:35--  https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70348401 (67M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>]  67.09M  88.5MB/s    in 0.8s
#
# 2019-07-23 15:38:35 (88.5 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [70348401/70348401]
#
# PREFIX=/usr/local
# reinstalling: python-3.7.3-h0371630_0 ...
# using -f (force) option
# Python 3.7.3
# reinstalling: ca-certificates-2019.1.23-0 ...
# using -f (force) option
# reinstalling: libgcc-ng-8.2.0-hdf63c60_1 ...
# using -f (force) option
# reinstalling: libstdcxx-ng-8.2.0-hdf63c60_1 ...
# using -f (force) option
# reinstalling: libffi-3.2.1-hd88cf55_4 ...
# using -f (force) option
# reinstalling: ncurses-6.1-he6710b0_1 ...
# using -f (force) option
# reinstalling: openssl-1.1.1b-h7b6447c_1 ...
# using -f (force) option
# reinstalling: xz-5.2.4-h14c3975_4 ...
# using -f (force) option
# reinstalling: yaml-0.1.7-had09818_2 ...
# using -f (force) option
# reinstalling: zlib-1.2.11-h7b6447c_3 ...
# using -f (force) option
# reinstalling: libedit-3.1.20181209-hc058e9b_0 ...
# using -f (force) option
# reinstalling: readline-7.0-h7b6447c_5 ...
# using -f (force) option
# reinstalling: tk-8.6.8-hbc83047_0 ...
# using -f (force) option
# reinstalling: sqlite-3.27.2-h7b6447c_0 ...
# using -f (force) option
# reinstalling: asn1crypto-0.24.0-py37_0 ...
# using -f (force) option
# reinstalling: certifi-2019.3.9-py37_0 ...
# using -f (force) option
# reinstalling: chardet-3.0.4-py37_1 ...
# using -f (force) option
# reinstalling: idna-2.8-py37_0 ...
# using -f (force) option
# reinstalling: pycosat-0.6.3-py37h14c3975_0 ...
# using -f (force) option
# reinstalling: pycparser-2.19-py37_0 ...
# using -f (force) option
# reinstalling: pysocks-1.6.8-py37_0 ...
# using -f (force) option
# reinstalling: ruamel_yaml-0.15.46-py37h14c3975_0 ...
# using -f (force) option
# reinstalling: six-1.12.0-py37_0 ...
# using -f (force) option
# reinstalling: cffi-1.12.2-py37h2e261b9_1 ...
# using -f (force) option
# reinstalling: setuptools-41.0.0-py37_0 ...
# using -f (force) option
# reinstalling: cryptography-2.6.1-py37h1ba5d50_0 ...
# using -f (force) option
# reinstalling: wheel-0.33.1-py37_0 ...
# using -f (force) option
# reinstalling: pip-19.0.3-py37_0 ...
# using -f (force) option
# reinstalling: pyopenssl-19.0.0-py37_0 ...
# using -f (force) option
# reinstalling: urllib3-1.24.1-py37_0 ...
# using -f (force) option
# reinstalling: requests-2.21.0-py37_0 ...
# using -f (force) option
# reinstalling: conda-4.6.14-py37_0 ...
# using -f (force) option
# using -f (force) option
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
#
# real	0m29.460s
# user	0m15.591s
# sys	0m2.881s
# y
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     boost-1.70.0               |   py37h9de70de_1         337 KB  conda-forge
#     boost-cpp-1.70.0           |       h8e57a91_2        21.1 MB  conda-forge
#     bzip2-1.0.8                |       h516909a_0         396 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     cairo-1.16.0               |    hfb77d84_1002         1.5 MB  conda-forge
#     certifi-2019.6.16          |           py37_1         149 KB  conda-forge
#     conda-4.7.10               |           py37_0         3.0 MB  conda-forge
#     conda-package-handling-1.3.11|           py37_0         257 KB  conda-forge
#     fontconfig-2.13.1          |    h86ecdb6_1001         340 KB  conda-forge
#     freetype-2.10.0            |       he983fc9_0         885 KB  conda-forge
#     gettext-0.19.8.1           |    hc5be6a0_1002         3.6 MB  conda-forge
#     glib-2.58.3                |    h6f030ca_1002         3.3 MB  conda-forge
#     icu-64.2                   |       he1b5a44_0        12.6 MB  conda-forge
#     jpeg-9c                    |    h14c3975_1001         251 KB  conda-forge
#     libarchive-3.3.3           |    hb44662c_1005         1.4 MB  conda-forge
#     libblas-3.8.0              |      10_openblas           6 KB  conda-forge
#     libcblas-3.8.0             |      10_openblas           6 KB  conda-forge
#     libgfortran-ng-7.3.0       |       hdf63c60_0         1.3 MB
#     libiconv-1.15              |    h516909a_1005         2.0 MB  conda-forge
#     liblapack-3.8.0            |      10_openblas           6 KB  conda-forge
#     libopenblas-0.3.6          |       h6e990d7_4         7.7 MB  conda-forge
#     libpng-1.6.37              |       hed695b0_0         343 KB  conda-forge
#     libtiff-4.0.10             |    h57b8799_1003         587 KB  conda-forge
#     libuuid-2.32.1             |    h14c3975_1000          26 KB  conda-forge
#     libxcb-1.13                |    h14c3975_1002         396 KB  conda-forge
#     libxml2-2.9.9              |       hee79883_2         1.3 MB  conda-forge
#     lz4-c-1.8.3                |    he1b5a44_1001         187 KB  conda-forge
#     lzo-2.10                   |    h14c3975_1000         319 KB  conda-forge
#     numpy-1.16.4               |   py37h95a1406_0         4.3 MB  conda-forge
#     olefile-0.46               |             py_0          31 KB  conda-forge
#     openblas-0.3.6             |       h6e990d7_4         8.2 MB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     pandas-0.25.0              |   py37hb3f55d8_0        11.4 MB  conda-forge
#     pcre-8.41                  |    hf484d3e_1003         249 KB  conda-forge
#     pillow-5.3.0               |py37h00a061d_1000         595 KB  conda-forge
#     pixman-0.38.0              |    h516909a_1003         594 KB  conda-forge
#     pthread-stubs-0.4          |    h14c3975_1001           5 KB  conda-forge
#     pycairo-1.18.1             |   py37h438ddbb_0          77 KB  conda-forge
#     python-dateutil-2.8.0      |             py_0         219 KB  conda-forge
#     python-libarchive-c-2.8    |        py37_1004          21 KB  conda-forge
#     pytz-2019.1                |             py_0         227 KB  conda-forge
#     rdkit-2019.03.2            |   py37hb31dc5d_1        23.3 MB  conda-forge
#     tqdm-4.32.2                |             py_0          41 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h14c3975_1002          26 KB  conda-forge
#     xorg-libice-1.0.10         |       h516909a_0          57 KB  conda-forge
#     xorg-libsm-1.2.3           |    h84519dc_1000          25 KB  conda-forge
#     xorg-libx11-1.6.8          |       h516909a_0         907 KB  conda-forge
#     xorg-libxau-1.0.9          |       h14c3975_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h516909a_0          18 KB  conda-forge
#     xorg-libxext-1.3.4         |       h516909a_0          51 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h516909a_1002          31 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h14c3975_1002           8 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h14c3975_1002          27 KB  conda-forge
#     xorg-xproto-7.0.31         |    h14c3975_1007          72 KB  conda-forge
#     zstd-1.4.0                 |       h3b9ef0a_0         928 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       116.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   boost              conda-forge/linux-64::boost-1.70.0-py37h9de70de_1
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.70.0-h8e57a91_2
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h516909a_0
#   cairo              conda-forge/linux-64::cairo-1.16.0-hfb77d84_1002
#   conda-package-han~ conda-forge/linux-64::conda-package-handling-1.3.11-py37_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.13.1-h86ecdb6_1001
#   freetype           conda-forge/linux-64::freetype-2.10.0-he983fc9_0
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-hc5be6a0_1002
#   glib               conda-forge/linux-64::glib-2.58.3-h6f030ca_1002
#   icu                conda-forge/linux-64::icu-64.2-he1b5a44_0
#   jpeg               conda-forge/linux-64::jpeg-9c-h14c3975_1001
#   libarchive         conda-forge/linux-64::libarchive-3.3.3-hb44662c_1005
#   libblas            conda-forge/linux-64::libblas-3.8.0-10_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.8.0-10_openblas
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.3.0-hdf63c60_0
#   libiconv           conda-forge/linux-64::libiconv-1.15-h516909a_1005
#   liblapack          conda-forge/linux-64::liblapack-3.8.0-10_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.6-h6e990d7_4
#   libpng             conda-forge/linux-64::libpng-1.6.37-hed695b0_0
#   libtiff            conda-forge/linux-64::libtiff-4.0.10-h57b8799_1003
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h14c3975_1000
#   libxcb             conda-forge/linux-64::libxcb-1.13-h14c3975_1002
#   libxml2            conda-forge/linux-64::libxml2-2.9.9-hee79883_2
#   lz4-c              conda-forge/linux-64::lz4-c-1.8.3-he1b5a44_1001
#   lzo                conda-forge/linux-64::lzo-2.10-h14c3975_1000
#   numpy              conda-forge/linux-64::numpy-1.16.4-py37h95a1406_0
#   olefile            conda-forge/noarch::olefile-0.46-py_0
#   openblas           conda-forge/linux-64::openblas-0.3.6-h6e990d7_4
#   pandas             conda-forge/linux-64::pandas-0.25.0-py37hb3f55d8_0
#   pcre               conda-forge/linux-64::pcre-8.41-hf484d3e_1003
#   pillow             conda-forge/linux-64::pillow-5.3.0-py37h00a061d_1000
#   pixman             conda-forge/linux-64::pixman-0.38.0-h516909a_1003
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h14c3975_1001
#   pycairo            conda-forge/linux-64::pycairo-1.18.1-py37h438ddbb_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.0-py_0
#   python-libarchive~ conda-forge/linux-64::python-libarchive-c-2.8-py37_1004
#   pytz               conda-forge/noarch::pytz-2019.1-py_0
#   rdkit              conda-forge/linux-64::rdkit-2019.03.2-py37hb31dc5d_1
#   tqdm               conda-forge/noarch::tqdm-4.32.2-py_0
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h14c3975_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h516909a_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-h84519dc_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.6.8-h516909a_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h14c3975_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h516909a_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h516909a_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h516909a_1002
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h14c3975_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h14c3975_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h14c3975_1007
#   zstd               conda-forge/linux-64::zstd-1.4.0-h3b9ef0a_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.1.23-0 --> conda-forge::ca-certificates-2019.6.16-hecc5488_0
#   certifi                pkgs/main::certifi-2019.3.9-py37_0 --> conda-forge::certifi-2019.6.16-py37_1
#   conda                      pkgs/main::conda-4.6.14-py37_0 --> conda-forge::conda-4.7.10-py37_0
#   openssl              pkgs/main::openssl-1.1.1b-h7b6447c_1 --> conda-forge::openssl-1.1.1c-h516909a_0
#
#
# y
# y
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# real	3m29.027s
# user	1m48.055s
# sys	0m9.773s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
import os
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
# !git clone https://github.com/aced125/RandomMatrixDiscriminant
# Out:
# Cloning into 'RandomMatrixDiscriminant'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.

# %%
# Out:
# 4

# %%
# Imports
import os
import functools

# RDkit, a chemoinformatics library
import rdkit
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
from rdkit.Chem import AllChem

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.decomposition import PCA

from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

import imageio

# %%
# Dataset loading functions for ChemBL datasets
def load_dataset(file_name, drop_non_binders = True):
    df = pd.read_csv(file_name, encoding = "ISO-8859-1")
    
    # Converting strings to floats, also set all non-numbers to NaN
    df['Standard Vaue'] = pd.to_numeric(df['Standard Value'],errors = 'coerce')

    # Drop Nans in affinity column
    df.dropna(subset = ['Standard Value'], inplace = True)
    df.reset_index(inplace = True)
    df = df.drop('index',axis = 1)
    
    # Filtering for only activities recorded in nanomolar affinity
    df = df[df['Standard Units'] == 'nM']    

    # Dropping any molecules that don't have a SMILES
    df = df.dropna(subset = ['Canonical Smiles'])
    
    # Considering only the binders (compounds with affinities of less than 1000nM)
    if drop_non_binders:
        df = df[df['Standard Value'] < 1000]
    
    # Dropping duplicate molecules
    df = df.drop_duplicates(subset = 'Canonical Smiles', keep = 'first')
    
    return df

# %%
df_train_test = load_dataset(os.path.join(os.getcwd(),'RandomMatrixDiscriminant/adr1b_chembl.csv'), drop_non_binders = True)
df_decoy = load_dataset(os.path.join(os.getcwd(), 'RandomMatrixDiscriminant/5ht1a_chembl.csv'), drop_non_binders = False)

# %%
smiles_train_test = df_train_test['Canonical Smiles']
smiles_train_test = smiles_train_test.reset_index()['Canonical Smiles']
affinity_train_test = df_train_test['Standard Value']

# Making 
binding_threshold = 1000  # units of nM
affinity_train_test = affinity_train_test.apply(lambda x: 1 if x<1000 else 0)

smiles_decoy = df_decoy['Canonical Smiles']
smiles_decoy = smiles_decoy.reset_index()['Canonical Smiles']
affinity_decoy = pd.Series([0 for i in range(len(smiles_decoy))])

# %%
# Generate image data

data = []
for x in df_train_test['Canonical Smiles']:
    img = np.array(rdkit.Chem.Draw.MolsToGridImage([rdkit.Chem.MolFromSmiles(x)],molsPerRow = 1))
    data.append(img)
for x in df_decoy['Canonical Smiles']:
    img = np.array(rdkit.Chem.Draw.MolsToGridImage([rdkit.Chem.MolFromSmiles(x)],molsPerRow = 1))
    data.append(img)

# %%
data = np.array(data)
y = np.concatenate((affinity_train_test,affinity_decoy))

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y, stratify = y, random_state = 3)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3723, 200, 200, 3), (1241, 200, 200, 3), (3723,), (1241,))

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.

# %%
# Training parameters
batch_size = 12
epochs = 200
data_augmentation = True
num_classes = 2

n = 3

subtract_pixel_mean = True

version = 1

if version == 1:
  depth = n*6 + 2
elif version == 2:
  depth = n*9 + 2

model_type = 'ResNet%dv%d' % (depth, version)

# %%
input_shape = X_train.shape[1:]
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

if subtract_pixel_mean:
  X_train_mean = np.mean(X_train, axis = 0)
  X_train -= X_train_mean
  X_test -= X_train_mean

# %%
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# X_train shape: (3723, 200, 200, 3)
# 3723 train samples
# 1241 test samples
# y_train shape: (3723,)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(1-y_train, num_classes)
y_test = keras.utils.to_categorical(1-y_test, num_classes)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=2):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=2):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 200, 200, 16) 448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 200, 200, 16) 64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 200, 200, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 200, 200, 16) 2320        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 200, 200, 16) 64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 200, 200, 16) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 200, 200, 16) 2320        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 200, 200, 16) 64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 200, 200, 16) 0           activation_20[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 200, 200, 16) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 200, 200, 16) 2320        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 200, 200, 16) 64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 200, 200, 16) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 200, 200, 16) 2320        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 200, 200, 16) 64          conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 200, 200, 16) 0           activation_22[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 200, 200, 16) 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 200, 200, 16) 2320        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 200, 200, 16) 64          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 200, 200, 16) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 200, 200, 16) 2320        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 200, 200, 16) 64          conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 200, 200, 16) 0           activation_24[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 200, 200, 16) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 100, 100, 32) 4640        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 100, 100, 32) 128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 100, 100, 32) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 100, 100, 32) 9248        activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 100, 100, 32) 544         activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 100, 100, 32) 128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 100, 100, 32) 0           conv2d_31[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 100, 100, 32) 0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 100, 100, 32) 9248        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 100, 100, 32) 128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 100, 100, 32) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 100, 100, 32) 9248        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 100, 100, 32) 128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 100, 100, 32) 0           activation_28[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 100, 100, 32) 0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 100, 100, 32) 9248        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 100, 100, 32) 128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 100, 100, 32) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 100, 100, 32) 9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 100, 100, 32) 128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 100, 100, 32) 0           activation_30[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 100, 100, 32) 0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 50, 50, 64)   18496       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 50, 50, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 50, 50, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 50, 50, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 50, 50, 64)   2112        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 50, 50, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 50, 50, 64)   0           conv2d_38[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 50, 50, 64)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 50, 64)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 50, 50, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 50, 50, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 50, 50, 64)   36928       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 50, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 50, 50, 64)   0           activation_34[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 50, 50, 64)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 50, 50, 64)   36928       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 50, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 50, 50, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 50, 50, 64)   36928       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 50, 50, 64)   0           activation_36[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 50, 50, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 6, 6, 64)     0           activation_38[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2304)         0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            4610        flatten_2[0][0]
# ==================================================================================================
# Total params: 278,402
# Trainable params: 277,026
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(X_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(X_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
    
    
    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(X_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size),
                        validation_data=(X_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks,
                       steps_per_epoch=X_train.shape[0]//batch_size)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 310/310 [==============================] - 54s 174ms/step - loss: 0.5932 - acc: 0.8398 - val_loss: 1.0503 - val_acc: 0.6906
#
# Epoch 00001: val_acc improved from -inf to 0.69057, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 143ms/step - loss: 0.4220 - acc: 0.8989 - val_loss: 0.5334 - val_acc: 0.8799
#
# Epoch 00002: val_acc improved from 0.69057 to 0.87994, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.3785 - acc: 0.9102 - val_loss: 0.4809 - val_acc: 0.9146
#
# Epoch 00003: val_acc improved from 0.87994 to 0.91459, saving model to /content/saved_models/cifar10_ResNet20v1_model.003.h5
# Epoch 4/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.3522 - acc: 0.9118 - val_loss: 0.3458 - val_acc: 0.9210
#
# Epoch 00004: val_acc improved from 0.91459 to 0.92103, saving model to /content/saved_models/cifar10_ResNet20v1_model.004.h5
# Epoch 5/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.3310 - acc: 0.9185 - val_loss: 0.5202 - val_acc: 0.9106
#
# Epoch 00005: val_acc did not improve from 0.92103
# Epoch 6/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.3178 - acc: 0.9228 - val_loss: 0.5421 - val_acc: 0.8155
#
# Epoch 00006: val_acc did not improve from 0.92103
# Epoch 7/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.2854 - acc: 0.9336 - val_loss: 1.3386 - val_acc: 0.2160
#
# Epoch 00007: val_acc did not improve from 0.92103
# Epoch 8/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.2767 - acc: 0.9352 - val_loss: 0.6272 - val_acc: 0.8904
#
# Epoch 00008: val_acc did not improve from 0.92103
# Epoch 9/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.2692 - acc: 0.9395 - val_loss: 0.2939 - val_acc: 0.9218
#
# Epoch 00009: val_acc improved from 0.92103 to 0.92184, saving model to /content/saved_models/cifar10_ResNet20v1_model.009.h5
# Epoch 10/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.2438 - acc: 0.9433 - val_loss: 0.6768 - val_acc: 0.9138
#
# Epoch 00010: val_acc did not improve from 0.92184
# Epoch 11/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.2488 - acc: 0.9425 - val_loss: 0.2972 - val_acc: 0.9049
#
# Epoch 00011: val_acc did not improve from 0.92184
# Epoch 12/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 143ms/step - loss: 0.2310 - acc: 0.9500 - val_loss: 0.2048 - val_acc: 0.9565
#
# Epoch 00012: val_acc improved from 0.92184 to 0.95649, saving model to /content/saved_models/cifar10_ResNet20v1_model.012.h5
# Epoch 13/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.2131 - acc: 0.9559 - val_loss: 1.5696 - val_acc: 0.8203
#
# Epoch 00013: val_acc did not improve from 0.95649
# Epoch 14/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.2168 - acc: 0.9500 - val_loss: 0.4675 - val_acc: 0.8364
#
# Epoch 00014: val_acc did not improve from 0.95649
# Epoch 15/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.1897 - acc: 0.9608 - val_loss: 0.2505 - val_acc: 0.9380
#
# Epoch 00015: val_acc did not improve from 0.95649
# Epoch 16/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.2100 - acc: 0.9497 - val_loss: 0.2902 - val_acc: 0.9388
#
# Epoch 00016: val_acc did not improve from 0.95649
# Epoch 17/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 143ms/step - loss: 0.1905 - acc: 0.9562 - val_loss: 0.2671 - val_acc: 0.9484
#
# Epoch 00017: val_acc did not improve from 0.95649
# Epoch 18/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.1880 - acc: 0.9618 - val_loss: 0.1910 - val_acc: 0.9613
#
# Epoch 00018: val_acc improved from 0.95649 to 0.96132, saving model to /content/saved_models/cifar10_ResNet20v1_model.018.h5
# Epoch 19/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.1818 - acc: 0.9632 - val_loss: 0.4030 - val_acc: 0.9049
#
# Epoch 00019: val_acc did not improve from 0.96132
# Epoch 20/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1773 - acc: 0.9621 - val_loss: 0.2827 - val_acc: 0.9009
#
# Epoch 00020: val_acc did not improve from 0.96132
# Epoch 21/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1719 - acc: 0.9634 - val_loss: 2.7220 - val_acc: 0.8203
#
# Epoch 00021: val_acc did not improve from 0.96132
# Epoch 22/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1806 - acc: 0.9599 - val_loss: 0.2105 - val_acc: 0.9388
#
# Epoch 00022: val_acc did not improve from 0.96132
# Epoch 23/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1701 - acc: 0.9672 - val_loss: 0.3038 - val_acc: 0.9162
#
# Epoch 00023: val_acc did not improve from 0.96132
# Epoch 24/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1649 - acc: 0.9659 - val_loss: 0.2071 - val_acc: 0.9549
#
# Epoch 00024: val_acc did not improve from 0.96132
# Epoch 25/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.1768 - acc: 0.9608 - val_loss: 0.1526 - val_acc: 0.9702
#
# Epoch 00025: val_acc improved from 0.96132 to 0.97019, saving model to /content/saved_models/cifar10_ResNet20v1_model.025.h5
# Epoch 26/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 142ms/step - loss: 0.1448 - acc: 0.9728 - val_loss: 0.2700 - val_acc: 0.9122
#
# Epoch 00026: val_acc did not improve from 0.97019
# Epoch 27/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.1726 - acc: 0.9629 - val_loss: 0.2188 - val_acc: 0.9404
#
# Epoch 00027: val_acc did not improve from 0.97019
# Epoch 28/200
# Learning rate:  0.001
# 310/310 [==============================] - 44s 141ms/step - loss: 0.1542 - acc: 0.9677 - val_loss: 0.1596 - val_acc: 0.9645
#
# Epoch 00028: val_acc did not improve from 0.97019
# Epoch 29/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1563 - acc: 0.9656 - val_loss: 0.7072 - val_acc: 0.7381
#
# Epoch 00029: val_acc did not improve from 0.97019
# Epoch 30/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1546 - acc: 0.9683 - val_loss: 0.2114 - val_acc: 0.9565
#
# Epoch 00030: val_acc did not improve from 0.97019
# Epoch 31/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1526 - acc: 0.9667 - val_loss: 0.3164 - val_acc: 0.9089
#
# Epoch 00031: val_acc did not improve from 0.97019
# Epoch 32/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1568 - acc: 0.9683 - val_loss: 0.3543 - val_acc: 0.8824
#
# Epoch 00032: val_acc did not improve from 0.97019
# Epoch 33/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1508 - acc: 0.9685 - val_loss: 0.1934 - val_acc: 0.9460
#
# Epoch 00033: val_acc did not improve from 0.97019
# Epoch 34/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1631 - acc: 0.9651 - val_loss: 0.1763 - val_acc: 0.9637
#
# Epoch 00034: val_acc did not improve from 0.97019
# Epoch 35/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1279 - acc: 0.9742 - val_loss: 0.1795 - val_acc: 0.9492
#
# Epoch 00035: val_acc did not improve from 0.97019
# Epoch 36/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1570 - acc: 0.9640 - val_loss: 1.1272 - val_acc: 0.4609
#
# Epoch 00036: val_acc did not improve from 0.97019
# Epoch 37/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1405 - acc: 0.9685 - val_loss: 0.1763 - val_acc: 0.9654
#
# Epoch 00037: val_acc did not improve from 0.97019
# Epoch 38/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1471 - acc: 0.9696 - val_loss: 0.2067 - val_acc: 0.9525
#
# Epoch 00038: val_acc did not improve from 0.97019
# Epoch 39/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1426 - acc: 0.9742 - val_loss: 0.1990 - val_acc: 0.9589
#
# Epoch 00039: val_acc did not improve from 0.97019
# Epoch 40/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.1387 - acc: 0.9707 - val_loss: 0.2360 - val_acc: 0.9307
#
# Epoch 00040: val_acc did not improve from 0.97019
# Epoch 41/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1430 - acc: 0.9683 - val_loss: 0.4129 - val_acc: 0.8799
#
# Epoch 00041: val_acc did not improve from 0.97019
# Epoch 42/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1295 - acc: 0.9734 - val_loss: 0.2076 - val_acc: 0.9460
#
# Epoch 00042: val_acc did not improve from 0.97019
# Epoch 43/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1264 - acc: 0.9731 - val_loss: 0.1500 - val_acc: 0.9621
#
# Epoch 00043: val_acc did not improve from 0.97019
# Epoch 44/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1351 - acc: 0.9710 - val_loss: 0.4126 - val_acc: 0.8541
#
# Epoch 00044: val_acc did not improve from 0.97019
# Epoch 45/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.1214 - acc: 0.9758 - val_loss: 0.2091 - val_acc: 0.9517
#
# Epoch 00045: val_acc did not improve from 0.97019
# Epoch 46/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1330 - acc: 0.9694 - val_loss: 0.2390 - val_acc: 0.9444
#
# Epoch 00046: val_acc did not improve from 0.97019
# Epoch 47/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1358 - acc: 0.9720 - val_loss: 0.2419 - val_acc: 0.9388
#
# Epoch 00047: val_acc did not improve from 0.97019
# Epoch 48/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1194 - acc: 0.9763 - val_loss: 0.1331 - val_acc: 0.9662
#
# Epoch 00048: val_acc did not improve from 0.97019
# Epoch 49/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1248 - acc: 0.9715 - val_loss: 0.2393 - val_acc: 0.9380
#
# Epoch 00049: val_acc did not improve from 0.97019
# Epoch 50/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1215 - acc: 0.9745 - val_loss: 0.1626 - val_acc: 0.9589
#
# Epoch 00050: val_acc did not improve from 0.97019
# Epoch 51/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1238 - acc: 0.9720 - val_loss: 0.3230 - val_acc: 0.9130
#
# Epoch 00051: val_acc did not improve from 0.97019
# Epoch 52/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1261 - acc: 0.9726 - val_loss: 0.3347 - val_acc: 0.9009
#
# Epoch 00052: val_acc did not improve from 0.97019
# Epoch 53/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1185 - acc: 0.9755 - val_loss: 0.4199 - val_acc: 0.8356
#
# Epoch 00053: val_acc did not improve from 0.97019
# Epoch 54/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1163 - acc: 0.9758 - val_loss: 0.2552 - val_acc: 0.9202
#
# Epoch 00054: val_acc did not improve from 0.97019
# Epoch 55/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1257 - acc: 0.9774 - val_loss: 0.3490 - val_acc: 0.9234
#
# Epoch 00055: val_acc did not improve from 0.97019
# Epoch 56/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1216 - acc: 0.9726 - val_loss: 0.2211 - val_acc: 0.9525
#
# Epoch 00056: val_acc did not improve from 0.97019
# Epoch 57/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1186 - acc: 0.9763 - val_loss: 0.1558 - val_acc: 0.9621
#
# Epoch 00057: val_acc did not improve from 0.97019
# Epoch 58/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1102 - acc: 0.9774 - val_loss: 0.1235 - val_acc: 0.9726
#
# Epoch 00058: val_acc improved from 0.97019 to 0.97260, saving model to /content/saved_models/cifar10_ResNet20v1_model.058.h5
# Epoch 59/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1372 - acc: 0.9694 - val_loss: 0.1758 - val_acc: 0.9549
#
# Epoch 00059: val_acc did not improve from 0.97260
# Epoch 60/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1085 - acc: 0.9780 - val_loss: 0.1723 - val_acc: 0.9605
#
# Epoch 00060: val_acc did not improve from 0.97260
# Epoch 61/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1268 - acc: 0.9702 - val_loss: 0.1943 - val_acc: 0.9468
#
# Epoch 00061: val_acc did not improve from 0.97260
# Epoch 62/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1132 - acc: 0.9761 - val_loss: 0.3032 - val_acc: 0.9089
#
# Epoch 00062: val_acc did not improve from 0.97260
# Epoch 63/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1144 - acc: 0.9761 - val_loss: 0.1427 - val_acc: 0.9645
#
# Epoch 00063: val_acc did not improve from 0.97260
# Epoch 64/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1050 - acc: 0.9801 - val_loss: 0.4201 - val_acc: 0.8566
#
# Epoch 00064: val_acc did not improve from 0.97260
# Epoch 65/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1071 - acc: 0.9782 - val_loss: 0.2962 - val_acc: 0.9355
#
# Epoch 00065: val_acc did not improve from 0.97260
# Epoch 66/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1152 - acc: 0.9750 - val_loss: 0.1587 - val_acc: 0.9613
#
# Epoch 00066: val_acc did not improve from 0.97260
# Epoch 67/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1134 - acc: 0.9761 - val_loss: 0.2881 - val_acc: 0.8969
#
# Epoch 00067: val_acc did not improve from 0.97260
# Epoch 68/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.0958 - acc: 0.9815 - val_loss: 0.2109 - val_acc: 0.9404
#
# Epoch 00068: val_acc did not improve from 0.97260
# Epoch 69/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1259 - acc: 0.9718 - val_loss: 0.4294 - val_acc: 0.8550
#
# Epoch 00069: val_acc did not improve from 0.97260
# Epoch 70/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1030 - acc: 0.9801 - val_loss: 0.1506 - val_acc: 0.9621
#
# Epoch 00070: val_acc did not improve from 0.97260
# Epoch 71/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1121 - acc: 0.9758 - val_loss: 0.2018 - val_acc: 0.9605
#
# Epoch 00071: val_acc did not improve from 0.97260
# Epoch 72/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 137ms/step - loss: 0.1080 - acc: 0.9772 - val_loss: 0.1199 - val_acc: 0.9694
#
# Epoch 00072: val_acc did not improve from 0.97260
# Epoch 73/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1039 - acc: 0.9820 - val_loss: 0.2552 - val_acc: 0.9452
#
# Epoch 00073: val_acc did not improve from 0.97260
# Epoch 74/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1081 - acc: 0.9747 - val_loss: 0.1938 - val_acc: 0.9597
#
# Epoch 00074: val_acc did not improve from 0.97260
# Epoch 75/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1024 - acc: 0.9782 - val_loss: 0.2219 - val_acc: 0.9533
#
# Epoch 00075: val_acc did not improve from 0.97260
# Epoch 76/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1080 - acc: 0.9774 - val_loss: 0.2171 - val_acc: 0.9380
#
# Epoch 00076: val_acc did not improve from 0.97260
# Epoch 77/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 137ms/step - loss: 0.0999 - acc: 0.9763 - val_loss: 0.1283 - val_acc: 0.9718
#
# Epoch 00077: val_acc did not improve from 0.97260
# Epoch 78/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1083 - acc: 0.9753 - val_loss: 0.1464 - val_acc: 0.9621
#
# Epoch 00078: val_acc did not improve from 0.97260
# Epoch 79/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.0999 - acc: 0.9774 - val_loss: 0.2109 - val_acc: 0.9307
#
# Epoch 00079: val_acc did not improve from 0.97260
# Epoch 80/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1004 - acc: 0.9798 - val_loss: 0.2498 - val_acc: 0.9315
#
# Epoch 00080: val_acc did not improve from 0.97260
# Epoch 81/200
# Learning rate:  0.001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.1051 - acc: 0.9728 - val_loss: 0.1503 - val_acc: 0.9686
#
# Epoch 00081: val_acc did not improve from 0.97260
# Epoch 82/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 138ms/step - loss: 0.0833 - acc: 0.9815 - val_loss: 0.1136 - val_acc: 0.9726
#
# Epoch 00082: val_acc did not improve from 0.97260
# Epoch 83/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 137ms/step - loss: 0.0808 - acc: 0.9855 - val_loss: 0.1117 - val_acc: 0.9726
#
# Epoch 00083: val_acc did not improve from 0.97260
# Epoch 84/200
# Learning rate:  0.0001
# 310/310 [==============================] - 45s 144ms/step - loss: 0.0777 - acc: 0.9863 - val_loss: 0.1161 - val_acc: 0.9726
#
# Epoch 00084: val_acc did not improve from 0.97260
# Epoch 85/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0823 - acc: 0.9823 - val_loss: 0.1084 - val_acc: 0.9718
#
# Epoch 00085: val_acc did not improve from 0.97260
# Epoch 86/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0741 - acc: 0.9863 - val_loss: 0.1101 - val_acc: 0.9726
#
# Epoch 00086: val_acc improved from 0.97260 to 0.97260, saving model to /content/saved_models/cifar10_ResNet20v1_model.086.h5
# Epoch 87/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0712 - acc: 0.9874 - val_loss: 0.1033 - val_acc: 0.9734
#
# Epoch 00087: val_acc improved from 0.97260 to 0.97341, saving model to /content/saved_models/cifar10_ResNet20v1_model.087.h5
# Epoch 88/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0814 - acc: 0.9839 - val_loss: 0.1094 - val_acc: 0.9742
#
# Epoch 00088: val_acc improved from 0.97341 to 0.97421, saving model to /content/saved_models/cifar10_ResNet20v1_model.088.h5
# Epoch 89/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0690 - acc: 0.9855 - val_loss: 0.1046 - val_acc: 0.9750
#
# Epoch 00089: val_acc improved from 0.97421 to 0.97502, saving model to /content/saved_models/cifar10_ResNet20v1_model.089.h5
# Epoch 90/200
# Learning rate:  0.0001
# 310/310 [==============================] - 45s 146ms/step - loss: 0.0793 - acc: 0.9852 - val_loss: 0.1045 - val_acc: 0.9766
#
# Epoch 00090: val_acc improved from 0.97502 to 0.97663, saving model to /content/saved_models/cifar10_ResNet20v1_model.090.h5
# Epoch 91/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0719 - acc: 0.9847 - val_loss: 0.1056 - val_acc: 0.9742
#
# Epoch 00091: val_acc did not improve from 0.97663
# Epoch 92/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0756 - acc: 0.9849 - val_loss: 0.1089 - val_acc: 0.9742
#
# Epoch 00092: val_acc did not improve from 0.97663
# Epoch 93/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 139ms/step - loss: 0.0675 - acc: 0.9852 - val_loss: 0.1055 - val_acc: 0.9758
#
# Epoch 00093: val_acc did not improve from 0.97663
# Epoch 94/200
# Learning rate:  0.0001
# 310/310 [==============================] - 43s 140ms/step - loss: 0.0674 - acc: 0.9860 - val_loss: 0.1052 - val_acc: 0.9734
#
# Epoch 00094: val_acc did not improve from 0.97663
# Epoch 95/200
# Learning rate:  0.0001
# 180/310 [================>.............] - ETA: 16s - loss: 0.0760 - acc: 0.9861
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-5a8d49059c28> in <module>()
#      62                         epochs=epochs, verbose=1, workers=4,
#      63                         callbacks=callbacks,
# ---> 64                        steps_per_epoch=X_train.shape[0]//batch_size)
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
